# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("big_startup_secsees_dataset.csv")
df.shape
# Out:
# (66368, 14)

# %%
df.head()
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list funding_total_usd  \
# 0                                              Media          10000000
# 1  Application Platforms|Real Time|Social Network...            700000
# 2                                  Apps|Games|Mobile           3406878
# 3                                        Curated Web           2000000
# 4                                           Software                 -
#
#       status country_code state_code                 region           city  \
# 0  operating          IND         16                 Mumbai         Mumbai
# 1  operating          USA         DE             DE - Other  Delaware City
# 2  operating          NaN        NaN                    NaN            NaN
# 3  operating          CHN         22                Beijing        Beijing
# 4  operating          USA         IL  Springfield, Illinois      Champaign
#
#    funding_rounds  founded_at first_funding_at last_funding_at
# 0               1         NaN       2015-01-05      2015-01-05
# 1               2  2014-09-04       2014-03-01      2014-10-14
# 2               1         NaN       2014-01-30      2014-01-30
# 3               1  2007-01-01       2008-03-19      2008-03-19
# 4               1  2010-01-01       2014-07-24      2014-07-24

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66368 entries, 0 to 66367
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   permalink          66368 non-null  object
#  1   name               66367 non-null  object
#  2   homepage_url       61310 non-null  object
#  3   category_list      63220 non-null  object
#  4   funding_total_usd  66368 non-null  object
#  5   status             66368 non-null  object
#  6   country_code       59410 non-null  object
#  7   state_code         57821 non-null  object
#  8   region             58338 non-null  object
#  9   city               58340 non-null  object
#  10  funding_rounds     66368 non-null  int64
#  11  founded_at         51147 non-null  object
#  12  first_funding_at   66344 non-null  object
#  13  last_funding_at    66368 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 7.1+ MB

# %%
df.describe()
# Out:
#        funding_rounds
# count    66368.000000
# mean         1.732522
# std          1.360251
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         19.000000

# %%
df.isnull().sum()
# Out:
# permalink                0
# name                     1
# homepage_url          5058
# category_list         3148
# funding_total_usd        0
# status                   0
# country_code          6958
# state_code            8547
# region                8030
# city                  8028
# funding_rounds           0
# founded_at           15221
# first_funding_at        24
# last_funding_at          0
# dtype: int64

# %%
df = df.dropna(subset=['founded_at'])

# %%
df.loc[:, 'country_code'] = df['country_code'].fillna('Unknown')

# %%
df = df.dropna(subset=['category_list'])

# %%
df = df.dropna(subset=['name'])

# %%
df['funding_total_usd'] = (
    df['funding_total_usd']
    .replace('-', np.nan)
    .str.replace(',', '', regex=False)
)

df['funding_total_usd'] = pd.to_numeric(
    df['funding_total_usd'],
    errors='coerce'
)

# %%
df['funding_bucket'] = pd.cut(
    df['funding_total_usd'],
    bins=[0, 1e6, 1e7, 1e8, 1e9],
    labels=['Low', 'Medium', 'High', 'Very High']
)

# %%
df['first_funding_at'] = df['first_funding_at'].fillna(df['last_funding_at'])

# %%
df.isnull().sum()
# Out:
# permalink               0
# name                    0
# homepage_url         2499
# category_list           0
# funding_total_usd       0
# status                  0
# country_code            0
# state_code           4268
# region               3802
# city                 3801
# funding_rounds          0
# founded_at              0
# first_funding_at        0
# last_funding_at         0
# dtype: int64

# %%
date_cols = ['founded_at', 'first_funding_at', 'last_funding_at']

for col in date_cols:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# %%
df['failed'] = df['status'].apply(
    lambda x: 1 if x == 'closed' else 0
)

# %%
df['failed'].value_counts()
# Out:
# failed
# 0    45993
# 1     3717
# Name: count, dtype: int64

# %%
current_year = pd.Timestamp.now().year

df['founded_year'] = df['founded_at'].dt.year
df['last_funding_year'] = df['last_funding_at'].dt.year

df['startup_age_years'] = np.where(
    df['failed'] == 1,
    df['last_funding_year'] - df['founded_year'],
    current_year - df['founded_year']
)

# %%
df = df[df['startup_age_years'] >= 0]

# %%
df['funding_rounds'] = pd.to_numeric(
    df['funding_rounds'],
    errors='coerce'
)

# %%
df['primary_category'] = df['category_list'].str.split('|').str[0]

# %%
upper_limit = df['funding_total_usd'].quantile(0.99)

df = df[df['funding_total_usd'] <= upper_limit]

# %%
df = df.dropna(subset=['founded_year', 'primary_category'])

# %%
df_clean = df[[
    'name',
    'primary_category',
    'country_code',
    'funding_total_usd',
    'funding_rounds',
    'status',
    'failed',
    'startup_age_years',
    'founded_year'
]]

df_clean.head()
# Out:
#                      name       primary_category country_code  \
# 1                :Qounter  Application Platforms          USA
# 3                 0-6.com            Curated Web          CHN
# 6  Ondine Biomedical Inc.          Biotechnology          CAN
# 7                  H2O.ai              Analytics          USA
# 8                One Inc.                 Mobile          USA
#
#    funding_total_usd  funding_rounds     status  failed  startup_age_years  \
# 1           700000.0               2  operating       0               12.0
# 3          2000000.0               1  operating       0               19.0
# 6           762851.0               2  operating       0               29.0
# 7         33600000.0               4  operating       0               15.0
# 8          1150050.0               3  operating       0               15.0
#
#    founded_year
# 1        2014.0
# 3        2007.0
# 6        1997.0
# 7        2011.0
# 8        2011.0

# %%
df_clean.to_csv("clean_startup_data.csv", index=False)
